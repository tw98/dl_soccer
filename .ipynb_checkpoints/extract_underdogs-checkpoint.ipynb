# %%
import pandas as pd
import os
import numpy as np
import json
from datetime import datetime
from statistics import mean

from organizeEventData import *

# %%
coaches_file = "/Users/tw/Desktop/Deep_Learning/Project/data/coaches.json"
players_file = "/Users/tw/Desktop/Deep_Learning/Project/data/players.json"
refs_file = "/Users/tw/Desktop/Deep_Learning/Project/data/referees.json"
teams_file = "/Users/tw/Desktop/Deep_Learning/Project/data/teams.json"

teamsFile = open(teams_file)
teams = json.load(teamsFile)
teamsFile.close()

# %%
df_matches = pd.read_json("/Users/tw/Desktop/Deep_Learning/Project/data/matches/matches_Italy.json").drop(columns=['venue', 'date', 'status', 'duration'])

# %%
def clean_team_names(team):
    return team_dict[team]

def extract_label_information(label):
    teams, score = label.split(',')
    home_team, away_team = [x for x in teams.split(' - ')]
    home_goals, away_goals = [int(x.replace(' ', '')) for x in score.split(' - ')]

    return home_team, away_team, home_goals, away_goals

def get_team_ids(teamsData):
    return list(teamsData.keys())

def extract_game_information(teamsData, teams):
    teamIds = list(teamsData.keys())
    
    for t_id in teamIds:
        if teamsData[t_id]['side'] == 'home':
            team1_id = t_id
            team1_name = teamNameFromId(int(t_id), teams)
            team1_goals = teamsData[t_id]['score']
        elif teamsData[t_id]['side'] == 'away': 
            team2_id = t_id
            team2_name = teamNameFromId(int(t_id), teams)
            team2_goals = teamsData[t_id]['score']
        else:
            print('ERROR: team ids')
    return team1_id, team1_name, team2_id, team2_name, team1_goals, team2_goals

df_matches['team1_id'], df_matches['team1_name'], df_matches['team2_id'], df_matches['team2_name'], df_matches['team1_goals'], df_matches['team2_goals'] = zip(*df_matches.apply(lambda x: extract_game_information(x['teamsData'], teams), axis='columns'))

# %%
df_matches.drop(columns=['roundId', 'gameweek', 'seasonId', 'dateutc', 'referees', 'competitionId'])
# Out:
#                                              teamsData  winner     wyId  \
# 0    {'3162': {'scoreET': 0, 'coachId': 251025, 'si...    3161  2576335
# 1    {'3158': {'scoreET': 0, 'coachId': 210119, 'si...    3158  2576336
# 2    {'3173': {'scoreET': 0, 'coachId': 251044, 'si...    3173  2576329
# 3    {'3165': {'scoreET': 0, 'coachId': 272970, 'si...    3165  2576330
# 4    {'3166': {'scoreET': 0, 'coachId': 20481, 'sid...    3163  2576331
# ..                                                 ...     ...      ...
# 375  {'3315': {'scoreET': 0, 'coachId': 261661, 'si...       0  2575967
# 376  {'3165': {'scoreET': 0, 'coachId': 21603, 'sid...    3165  2575968
# 377  {'3172': {'scoreET': 0, 'coachId': 210116, 'si...    3158  2575959
# 378  {'3194': {'scoreET': 0, 'coachId': 270032, 'si...    3187  2575962
# 379  {'3159': {'scoreET': 0, 'coachId': 20386, 'sid...    3159  2575964
#
#                              label team1_id     team1_name team2_id  \
# 0    Lazio - Internazionale, 2 - 3     3162          Lazio     3161
# 1           Sassuolo - Roma, 0 - 1     3315       Sassuolo     3158
# 2       Cagliari - Atalanta, 1 - 0     3173       Cagliari     3172
# 3        Chievo - Benevento, 1 - 0     3165         Chievo     3219
# 4         Udinese - Bologna, 1 - 0     3163        Udinese     3166
# ..                             ...      ...            ...      ...
# 375        Sassuolo - Genoa, 0 - 0     3315       Sassuolo     3193
# 376        Udinese - Chievo, 1 - 2     3163        Udinese     3165
# 377         Atalanta - Roma, 0 - 1     3172       Atalanta     3158
# 378  Hellas Verona - Napoli, 1 - 3     3194  Hellas Verona     3187
# 379     Juventus - Cagliari, 3 - 0     3159       Juventus     3173
#
#          team2_name  team1_goals  team2_goals
# 0    Internazionale            2            3
# 1              Roma            0            1
# 2          Atalanta            1            0
# 3         Benevento            1            0
# 4           Bologna            1            0
# ..              ...          ...          ...
# 375           Genoa            0            0
# 376          Chievo            1            2
# 377            Roma            0            1
# 378          Napoli            1            3
# 379        Cagliari            3            0
#
# [380 rows x 10 columns]

# %%
teams = ['Arsenal', 'Brighton', 'Chelsea', 'Crystal Palace', 'Everton',
       'Southampton', 'Watford', 'West Brom', 'Man United', 'Newcastle',
       'Bournemouth', 'Burnley', 'Leicester', 'Liverpool', 'Stoke',
       'Swansea', 'Huddersfield', 'Tottenham', 'Man City', 'West Ham']
teams.sort()
teams
# Out:
# ['Arsenal',
#  'Bournemouth',
#  'Brighton',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Huddersfield',
#  'Leicester',
#  'Liverpool',
#  'Man City',
#  'Man United',
#  'Newcastle',
#  'Southampton',
#  'Stoke',
#  'Swansea',
#  'Tottenham',
#  'Watford',
#  'West Brom',
#  'West Ham']

# %%
team_dict = {
    # Germany
    'Augsburg': 'Augsburg',
    'BayernM\\u00fcnchen': 'Bayern Munich',
    'BorussiaDortmund': 'Dortmund',
    'EintrachtFrankfurt': 'Ein Frankfurt',
    'K\\u00f6ln': 'FC Koln',
    'Freiburg': 'Freiburg',
    'HamburgerSV': 'Hamburg',
    'Hannover96': 'Hannover',
    'HerthaBSC': 'Hertha',
    'Hoffenheim': 'Hoffenheim',
    'BayerLeverkusen': 'Leverkusen',
    "BorussiaM'gladbach": "M'gladbach",
    'Mainz05': 'Mainz',
    'RBLeipzig': 'RB Leipzig',
    'Schalke04': 'Schalke 04',
    'Stuttgart': 'Stuttgart',
    'WerderBremen': 'Werder Bremen',
    'Wolfsburg': 'Wolfsburg',

    # England
    "Arsenal": 'Arsenal',
    "AFCBournemouth": 'Bournemouth',
    "Brighton&HoveAlbion": 'Brighton',
    "Burnley": 'Burnley',
    "Chelsea": 'Chelsea',
    "CrystalPalace": 'Crystal Palace',
    "Everton": 'Everton',
    "HuddersfieldTown": 'Huddersfield',
    "LeicesterCity": 'Leicester',
    "Liverpool": 'Liverpool',
    "ManchesterCity": 'Man City',
    "ManchesterUnited": 'Man United',
    "NewcastleUnited": 'Newcastle',
    "Southampton": 'Southampton',
    "StokeCity": 'Stoke',
    "SwanseaCity": 'Swansea',
    "TottenhamHotspur": 'Tottenham',
    "Watford": 'Watford',
    "WestBromwichAlbion": 'West Brom',
    "WestHamUnited": 'West Ham',

    # Spain
    "DeportivoAlav\\u00e9s": 'Alaves',
    "AthleticClub": 'Ath Bilbao',
    "Atl\\u00e9ticoMadrid": 'Ath Madrid',
    "Barcelona": 'Barcelona',
    "RealBetis": 'Betis',
    "CeltadeVigo": 'Celta',
    "Eibar": 'Eibar',
    "Espanyol": 'Espanol',
    "Getafe": 'Getafe',
    "Girona": 'Girona',
    "DeportivoLaCoru\\u00f1a": 'La Coruna',
    "LasPalmas": 'Las Palmas',
    "Legan\\u00e9s": 'Leganes',
    "Levante": 'Levante',
    "M\\u00e1laga": 'Malaga',
    "RealMadrid": 'Real Madrid',
    "Sevilla": 'Sevilla',
    "RealSociedad": 'Sociedad',
    "Valencia": 'Valencia',
    "Villarreal": 'Villarreal',

    # France
    "AmiensSC": 'Amiens',
    "AngersSCO": 'Angers',
    "Bordeaux": 'Bordeaux',
    "Caen": 'Caen',
    "Dijon": 'Dijon',
    "Guingamp": 'Guingamp',
    "Lille": 'Lille',
    "OlympiqueLyonnais": 'Lyon',
    "OlympiqueMarseille": 'Marseille',
    "Metz": 'Metz',
    "Monaco": 'Monaco',
    "Montpellier": 'Montpellier',
    "Nantes": 'Nantes',
    "Nice": 'Nice',
    "PSG": 'Paris SG',
    "Rennes": 'Rennes',
    "Saint-\\u00c9tienne": 'St Etienne',
    "Strasbourg": 'Strasbourg',
    "Toulouse": 'Toulouse',
    "Troyes": 'Troyes',

    # Italy
    "Atalanta": 'Atalanta',
    "Benevento": 'Benevento',
    "Bologna": 'Bologna',
    "Cagliari": 'Cagliari',
    "Chievo": 'Chievo',
    "Crotone": 'Crotone',
    "Fiorentina": 'Fiorentina',
    "Genoa": 'Genoa',
    "Internazionale": 'Inter',
    "Juventus": 'Juventus',
    "Lazio": 'Lazio',
    "Milan": 'Milan',
    "Napoli": 'Napoli',
    "Roma": 'Roma',
    "Sampdoria": 'Sampdoria',
    "Sassuolo": 'Sassuolo',
    "SPAL": 'Spal',
    "Torino": 'Torino',
    "Udinese": 'Udinese',
    "HellasVerona": 'Verona'

}


def clean_team_names(team):
    return team_dict[team]

def extract_label_information(label):
    teams, score = label.split(',')
    home_team, away_team = [clean_team_names(x.replace(' ', '')) for x in teams.split(' - ')]
    # home_team, away_team = [(x.replace(' ', '')) for x in teams.split(' - ')]
    home_goals, away_goals = [int(x.replace(' ', '')) for x in score.split(' - ')]

    return home_team, away_team, home_goals, away_goals

df_matches['HomeTeam'], df_matches['AwayTeam'], df_matches['HomeGoals'], df_matches['AwayGoals'] = zip(*df_matches.apply(lambda x: extract_label_information(x['label']), axis='columns'))

# %%
teams2 = (list(df_matches['team1_name'].unique()))
teams2.sort()
teams2
# Out:
# ['Atalanta',
#  'Benevento',
#  'Bologna',
#  'Cagliari',
#  'Chievo',
#  'Crotone',
#  'Fiorentina',
#  'Genoa',
#  'Hellas Verona',
#  'Internazionale',
#  'Juventus',
#  'Lazio',
#  'Milan',
#  'Napoli',
#  'Roma',
#  'SPAL',
#  'Sampdoria',
#  'Sassuolo',
#  'Torino',
#  'Udinese']

# %%
df_odds = (pd.read_csv('/Users/tw/Desktop/Deep_Learning/Project/data/odds/italy_odds.csv', usecols=['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'B365H', 'B365A', 'BWH','BWA', 'IWH', 'IWA', 'LBH', 'LBA', 'PSH','PSA', 'WHH','WHA','VCH', 'VCA'])).rename(columns={'FTHG': 'HomeGoals', 'FTAG': 'AwayGoals'})
df_odds['avgHome'] = df_odds.apply(lambda x: mean([x['B365H'], x['BWH'], x['IWH'], x['LBH'], x['PSH'], x['WHH'], x['VCH']]), axis='columns')
df_odds['avgAway'] = df_odds.apply(lambda x: mean([x['B365A'], x['BWA'], x['IWA'], x['LBA'], x['PSA'], x['WHA'], x['VCA']]), axis='columns')
df_odds = df_odds.drop(columns=['B365H', 'B365A', 'BWH','BWA', 'IWH', 'IWA', 'LBH', 'LBA', 'PSH','PSA', 'WHH','WHA','VCH', 'VCA'])

# %%
teams = (list(df_odds['HomeTeam'].unique()))
teams.sort()
teams
# Out:
# ['Atalanta',
#  'Benevento',
#  'Bologna',
#  'Cagliari',
#  'Chievo',
#  'Crotone',
#  'Fiorentina',
#  'Genoa',
#  'Inter',
#  'Juventus',
#  'Lazio',
#  'Milan',
#  'Napoli',
#  'Roma',
#  'Sampdoria',
#  'Sassuolo',
#  'Spal',
#  'Torino',
#  'Udinese',
#  'Verona']

# %%
df_odds
# Out:
#          Date  HomeTeam    AwayTeam  HomeGoals  AwayGoals   avgHome    avgAway
# 0    19/08/17  Juventus    Cagliari          3          0  1.147143  20.491429
# 1    19/08/17    Verona      Napoli          1          3  7.822857   1.410000
# 2    20/08/17  Atalanta        Roma          0          1  3.138571   2.272857
# 3    20/08/17   Bologna      Torino          1          1  3.112857   2.345714
# 4    20/08/17   Crotone       Milan          0          3  5.734286   1.594286
# ..        ...       ...         ...        ...        ...       ...        ...
# 375  20/05/18     Milan  Fiorentina          5          1  1.815714   4.277143
# 376  20/05/18    Napoli     Crotone          2          1  1.508571   5.790000
# 377  20/05/18  Sassuolo        Roma          0          1  4.148571   1.850000
# 378  20/05/18      Spal   Sampdoria          3          1  1.602857   5.512857
# 379  20/05/18   Udinese     Bologna          1          0  1.482857   6.812857
#
# [380 rows x 7 columns]

# %%
def isUnderdog(avg_1, avg_2):
    underdog_threshold = 5
    
    underdog_match = 0
    underdog_1 = 0
    underdog_2 = 0

    if avg_1 - avg_2 > underdog_threshold:
        underdog_1 = 1
        underdog_match = 1
    if avg_2 - avg_1 > underdog_threshold:
        underdog_2 = 1
        underdog_match = 1
    
    return underdog_match, underdog_1, underdog_2

df_odds['UnderdogMatch'], df_odds['HomeUnderdog'], df_odds['AwayUnderdog'] = zip(*df_odds.apply(lambda x: isUnderdog(x['avgHome'], x['avgAway']), axis='columns'))

# %%
df_odds
# Out:
#          Date  HomeTeam    AwayTeam  HomeGoals  AwayGoals   avgHome  \
# 0    19/08/17  Juventus    Cagliari          3          0  1.147143
# 1    19/08/17    Verona      Napoli          1          3  7.822857
# 2    20/08/17  Atalanta        Roma          0          1  3.138571
# 3    20/08/17   Bologna      Torino          1          1  3.112857
# 4    20/08/17   Crotone       Milan          0          3  5.734286
# ..        ...       ...         ...        ...        ...       ...
# 375  20/05/18     Milan  Fiorentina          5          1  1.815714
# 376  20/05/18    Napoli     Crotone          2          1  1.508571
# 377  20/05/18  Sassuolo        Roma          0          1  4.148571
# 378  20/05/18      Spal   Sampdoria          3          1  1.602857
# 379  20/05/18   Udinese     Bologna          1          0  1.482857
#
#        avgAway  UnderdogMatch  HomeUnderdog  AwayUnderdog
# 0    20.491429              1             0             1
# 1     1.410000              1             1             0
# 2     2.272857              0             0             0
# 3     2.345714              0             0             0
# 4     1.594286              0             0             0
# ..         ...            ...           ...           ...
# 375   4.277143              0             0             0
# 376   5.790000              0             0             0
# 377   1.850000              0             0             0
# 378   5.512857              0             0             0
# 379   6.812857              1             0             1
#
# [380 rows x 10 columns]

# %%
df_matches
# Out:
#      roundId  gameweek                                          teamsData  \
# 0    4406278        38  {'3162': {'scoreET': 0, 'coachId': 251025, 'si...
# 1    4406278        38  {'3158': {'scoreET': 0, 'coachId': 210119, 'si...
# 2    4406278        38  {'3173': {'scoreET': 0, 'coachId': 251044, 'si...
# 3    4406278        38  {'3165': {'scoreET': 0, 'coachId': 272970, 'si...
# 4    4406278        38  {'3166': {'scoreET': 0, 'coachId': 20481, 'sid...
# ..       ...       ...                                                ...
# 375  4406278         1  {'3315': {'scoreET': 0, 'coachId': 261661, 'si...
# 376  4406278         1  {'3165': {'scoreET': 0, 'coachId': 21603, 'sid...
# 377  4406278         1  {'3172': {'scoreET': 0, 'coachId': 210116, 'si...
# 378  4406278         1  {'3194': {'scoreET': 0, 'coachId': 270032, 'si...
# 379  4406278         1  {'3159': {'scoreET': 0, 'coachId': 20386, 'sid...
#
#      seasonId              dateutc  winner     wyId  \
# 0      181248  2018-05-20 18:45:00    3161  2576335
# 1      181248  2018-05-20 18:45:00    3158  2576336
# 2      181248  2018-05-20 16:00:00    3173  2576329
# 3      181248  2018-05-20 16:00:00    3165  2576330
# 4      181248  2018-05-20 16:00:00    3163  2576331
# ..        ...                  ...     ...      ...
# 375    181248  2017-08-20 18:45:00       0  2575967
# 376    181248  2017-08-20 18:45:00    3165  2575968
# 377    181248  2017-08-20 16:00:00    3158  2575959
# 378    181248  2017-08-19 18:45:00    3187  2575962
# 379    181248  2017-08-19 16:00:00    3159  2575964
#
#                              label  \
# 0    Lazio - Internazionale, 2 - 3
# 1           Sassuolo - Roma, 0 - 1
# 2       Cagliari - Atalanta, 1 - 0
# 3        Chievo - Benevento, 1 - 0
# 4         Udinese - Bologna, 1 - 0
# ..                             ...
# 375        Sassuolo - Genoa, 0 - 0
# 376        Udinese - Chievo, 1 - 2
# 377         Atalanta - Roma, 0 - 1
# 378  Hellas Verona - Napoli, 1 - 3
# 379     Juventus - Cagliari, 3 - 0
#
#                                               referees  competitionId  \
# 0    [{'refereeId': 377206, 'role': 'referee'}, {'r...            524
# 1    [{'refereeId': 377255, 'role': 'referee'}, {'r...            524
# 2    [{'refereeId': 377247, 'role': 'referee'}, {'r...            524
# 3    [{'refereeId': 377246, 'role': 'referee'}, {'r...            524
# 4    [{'refereeId': 377254, 'role': 'referee'}, {'r...            524
# ..                                                 ...            ...
# 375  [{'refereeId': 377233, 'role': 'referee'}, {'r...            524
# 376  [{'refereeId': 377254, 'role': 'referee'}, {'r...            524
# 377  [{'refereeId': 377248, 'role': 'referee'}, {'r...            524
# 378  [{'refereeId': 377252, 'role': 'referee'}, {'r...            524
# 379  [{'refereeId': 377263, 'role': 'referee'}, {'r...            524
#
#     team1_id     team1_name team2_id      team2_name  team1_goals  \
# 0       3162          Lazio     3161  Internazionale            2
# 1       3315       Sassuolo     3158            Roma            0
# 2       3173       Cagliari     3172        Atalanta            1
# 3       3165         Chievo     3219       Benevento            1
# 4       3163        Udinese     3166         Bologna            1
# ..       ...            ...      ...             ...          ...
# 375     3315       Sassuolo     3193           Genoa            0
# 376     3163        Udinese     3165          Chievo            1
# 377     3172       Atalanta     3158            Roma            0
# 378     3194  Hellas Verona     3187          Napoli            1
# 379     3159       Juventus     3173        Cagliari            3
#
#      team2_goals  HomeTeam   AwayTeam  HomeGoals  AwayGoals
# 0              3     Lazio      Inter          2          3
# 1              1  Sassuolo       Roma          0          1
# 2              0  Cagliari   Atalanta          1          0
# 3              0    Chievo  Benevento          1          0
# 4              0   Udinese    Bologna          1          0
# ..           ...       ...        ...        ...        ...
# 375            0  Sassuolo      Genoa          0          0
# 376            2   Udinese     Chievo          1          2
# 377            1  Atalanta       Roma          0          1
# 378            3    Verona     Napoli          1          3
# 379            0  Juventus   Cagliari          3          0
#
# [380 rows x 20 columns]

# %%
df_merged = df_matches.merge(df_odds, on=['HomeTeam', 'AwayTeam', 'HomeGoals', 'AwayGoals'])

# %%
print(df_matches.shape)
print(df_odds.shape)
print(df_merged.shape)
# Out:
# (380, 20)
# (380, 10)
# (380, 26)

# %%
underdog_matches = df_merged[df_merged['UnderdogMatch'] == 1].reset_index(drop=True)
underdog_matches
# Out:
#      roundId  gameweek                                          teamsData  \
# 0    4406278        38  {'3166': {'scoreET': 0, 'coachId': 20481, 'sid...
# 1    4406278        37  {'3315': {'scoreET': 0, 'coachId': 20603, 'sid...
# 2    4406278        36  {'3173': {'scoreET': 0, 'coachId': 251044, 'si...
# 3    4406278        36  {'3204': {'scoreET': 0, 'coachId': 357389, 'si...
# 4    4406278        36  {'3185': {'scoreET': 0, 'coachId': 21155, 'sid...
# ..       ...       ...                                                ...
# 120  4406278         2  {'3172': {'scoreET': 0, 'coachId': 210116, 'si...
# 121  4406278         2  {'3159': {'scoreET': 0, 'coachId': 20386, 'sid...
# 122  4406278         1  {'3204': {'scoreET': 0, 'coachId': 357389, 'si...
# 123  4406278         1  {'3194': {'scoreET': 0, 'coachId': 270032, 'si...
# 124  4406278         1  {'3159': {'scoreET': 0, 'coachId': 20386, 'sid...
#
#      seasonId              dateutc  winner     wyId  \
# 0      181248  2018-05-20 16:00:00    3163  2576331
# 1      181248  2018-05-12 18:45:00    3315  2576326
# 2      181248  2018-05-06 18:45:00    3158  2576316
# 3      181248  2018-05-06 13:00:00    3204  2576310
# 4      181248  2018-05-06 13:00:00       0  2576318
# ..        ...                  ...     ...      ...
# 120    181248  2017-08-27 18:45:00    3187  2575975
# 121    181248  2017-08-26 16:00:00    3159  2575973
# 122    181248  2017-08-20 18:45:00       0  2575965
# 123    181248  2017-08-19 18:45:00    3187  2575962
# 124    181248  2017-08-19 16:00:00    3159  2575964
#
#                                 label  \
# 0            Udinese - Bologna, 1 - 0
# 1    Internazionale - Sassuolo, 1 - 2
# 2              Cagliari - Roma, 0 - 1
# 3             SPAL - Benevento, 2 - 0
# 4              Napoli - Torino, 2 - 2
# ..                                ...
# 120          Napoli - Atalanta, 3 - 1
# 121           Genoa - Juventus, 2 - 4
# 122               Lazio - SPAL, 0 - 0
# 123     Hellas Verona - Napoli, 1 - 3
# 124        Juventus - Cagliari, 3 - 0
#
#                                               referees  competitionId  ...  \
# 0    [{'refereeId': 377254, 'role': 'referee'}, {'r...            524  ...
# 1    [{'refereeId': 377271, 'role': 'referee'}, {'r...            524  ...
# 2    [{'refereeId': 377256, 'role': 'referee'}, {'r...            524  ...
# 3    [{'refereeId': 377241, 'role': 'referee'}, {'r...            524  ...
# 4    [{'refereeId': 377244, 'role': 'referee'}, {'r...            524  ...
# ..                                                 ...            ...  ...
# 120  [{'refereeId': 377256, 'role': 'referee'}, {'r...            524  ...
# 121  [{'refereeId': 377231, 'role': 'referee'}, {'r...            524  ...
# 122  [{'refereeId': 377271, 'role': 'referee'}, {'r...            524  ...
# 123  [{'refereeId': 377252, 'role': 'referee'}, {'r...            524  ...
# 124  [{'refereeId': 377263, 'role': 'referee'}, {'r...            524  ...
#
#      HomeTeam   AwayTeam HomeGoals AwayGoals      Date   avgHome    avgAway  \
# 0     Udinese    Bologna         1         0  20/05/18  1.482857   6.812857
# 1       Inter   Sassuolo         1         2  12/05/18  1.161429  16.175714
# 2    Cagliari       Roma         0         1  06/05/18  8.097143   1.414286
# 3        Spal  Benevento         2         0  06/05/18  1.507143   6.570000
# 4      Napoli     Torino         2         2  06/05/18  1.244286  12.108571
# ..        ...        ...       ...       ...       ...       ...        ...
# 120    Napoli   Atalanta         3         1  27/08/17  1.391429   8.105714
# 121     Genoa   Juventus         2         4  26/08/17  8.772857   1.382857
# 122     Lazio       Spal         0         0  20/08/17  1.291429  11.021429
# 123    Verona     Napoli         1         3  19/08/17  7.822857   1.410000
# 124  Juventus   Cagliari         3         0  19/08/17  1.147143  20.491429
#
#     UnderdogMatch  HomeUnderdog  AwayUnderdog
# 0               1             0             1
# 1               1             0             1
# 2               1             1             0
# 3               1             0             1
# 4               1             0             1
# ..            ...           ...           ...
# 120             1             0             1
# 121             1             1             0
# 122             1             0             1
# 123             1             1             0
# 124             1             0             1
#
# [125 rows x 26 columns]

# %%
underdog_matches = underdog_matches.drop(columns=['roundId', 'gameweek', 'teamsData', 'seasonId', 'dateutc', 'referees', 'competitionId', 'HomeTeam','AwayTeam', 'HomeGoals', 'AwayGoals', 'Date'])
# Out:
#      winner     wyId                             label team1_id  \
# 0      3163  2576331          Udinese - Bologna, 1 - 0     3163
# 1      3315  2576326  Internazionale - Sassuolo, 1 - 2     3161
# 2      3158  2576316            Cagliari - Roma, 0 - 1     3173
# 3      3204  2576310           SPAL - Benevento, 2 - 0     3204
# 4         0  2576318            Napoli - Torino, 2 - 2     3187
# ..      ...      ...                               ...      ...
# 120    3187  2575975          Napoli - Atalanta, 3 - 1     3187
# 121    3159  2575973           Genoa - Juventus, 2 - 4     3193
# 122       0  2575965               Lazio - SPAL, 0 - 0     3162
# 123    3187  2575962     Hellas Verona - Napoli, 1 - 3     3194
# 124    3159  2575964        Juventus - Cagliari, 3 - 0     3159
#
#          team1_name team2_id team2_name  team1_goals  team2_goals   avgHome  \
# 0           Udinese     3166    Bologna            1            0  1.482857
# 1    Internazionale     3315   Sassuolo            1            2  1.161429
# 2          Cagliari     3158       Roma            0            1  8.097143
# 3              SPAL     3219  Benevento            2            0  1.507143
# 4            Napoli     3185     Torino            2            2  1.244286
# ..              ...      ...        ...          ...          ...       ...
# 120          Napoli     3172   Atalanta            3            1  1.391429
# 121           Genoa     3159   Juventus            2            4  8.772857
# 122           Lazio     3204       SPAL            0            0  1.291429
# 123   Hellas Verona     3187     Napoli            1            3  7.822857
# 124        Juventus     3173   Cagliari            3            0  1.147143
#
#        avgAway  UnderdogMatch  HomeUnderdog  AwayUnderdog
# 0     6.812857              1             0             1
# 1    16.175714              1             0             1
# 2     1.414286              1             1             0
# 3     6.570000              1             0             1
# 4    12.108571              1             0             1
# ..         ...            ...           ...           ...
# 120   8.105714              1             0             1
# 121   1.382857              1             1             0
# 122  11.021429              1             0             1
# 123   1.410000              1             1             0
# 124  20.491429              1             0             1
#
# [125 rows x 14 columns]

# %%
underdog_matches.to_csv(f'data/underdogs/{country}.csv', index=False)
